# %% [markdown]
# # 02 — Ingest and Extract into Schema
#
# This notebook normalizes an unstructured invoice, compares line-oriented and regex extraction nodes, projects an exact schema, verifies every required field independently, and retains route and artifact evidence. Replace the text nodes with PDF, OCR, translation, chunking, or LLM packs without changing the executor.

# %%
from solutiongraph.examples import run_example

report = run_example(
    "document-to-schema",
    route="all",
    artifact_root=".artifacts/document-to-schema",
)
report

# %%
[(r["accepted"], r["verification_details"]) for r in report["experiment"]["receipts"]]
