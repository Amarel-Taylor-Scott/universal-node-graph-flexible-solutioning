# %% [markdown]
# # 03 — Check and Process Image
#
# This notebook decodes a real ASCII PGM image through two decoder nodes, compares an explicit no-op with min–max contrast enhancement, measures the result through direct and histogram strategies, and independently verifies image dimensions and contrast. Pillow, OpenCV, OCR, forensic, and vision-model nodes can implement the same typed slots.

# %%
from solutiongraph.examples import run_example

report = run_example(
    "image-check-and-process",
    route="all",
    artifact_root=".artifacts/image-check-and-process",
)
report

# %%
[(r["accepted"], r["metrics"]["quality"], r["verification_details"]["report"]) for r in report["experiment"]["receipts"]]
