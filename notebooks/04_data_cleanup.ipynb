# %% [markdown]
# # 04 — Data Cleanup
#
# This notebook compares conservative and aggressive normalization with exact and normalized entity deduplication. One valid route is deliberately rejected by the independent data-quality oracle; that negative evidence remains in the experiment ledger instead of being hidden.

# %%
from solutiongraph.examples import run_example

report = run_example(
    "data-cleanup",
    route="all",
    artifact_root=".artifacts/data-cleanup",
)
report

# %%
[(r["outcome"], r["verification_details"]) for r in report["experiment"]["receipts"]]
